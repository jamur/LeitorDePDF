# %%
import yfinance as yf
from datetime import timedelta, datetime

apple = yf.Ticker("AAPL")
informacoes = apple.info
f = datetime.utc
f = datetime.utcfromtimestamp(informacoes['firstTradeDateEpochUtc']).date()
print(f)
history = apple.history(start=f, end=f + timedelta(1))
print(history.iloc[0,0])
print(yf.Ticker("aapl").fast_info['lastPrice'])
history = co.history(period = "1d")
lastValue = history.iloc[-1,0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_198475/4004438009.py in <module>
#       4 apple = yf.Ticker("AAPL")
#       5 informacoes = apple.info
# ----> 6 f = datetime.utc
#       7 f = datetime.utcfromtimestamp(informacoes['firstTradeDateEpochUtc']).date()
#       8 print(f)
#
# AttributeError: type object 'datetime.datetime' has no attribute 'utc'

# %%
apple = yf.Ticker("AAPL")
informacoes = apple.info
history = apple.history(period="1d")
lastValue = history.iloc[-1,0]
lastValue
# Out:
# 173.0500030517578

# %%
import yfinance as yf

print(yf.Ticker("aapl").fast_info['lastPrice'])
# Out:
# 173.57000732421875

# %%
import PyPDF2
import re
import pandas as pd
import yfinance as yf

# TODO API yahoo finance

pdf_file = open('ru2000_membershiplist_20220624_0.pdf', 'rb')
read_pdf = PyPDF2.PdfReader(pdf_file)
pages = read_pdf.pages
p = 0
#df = pd.DataFrame(columns = ['Company', 'Ticker', 'IPO', 'First Value', 'Last Value', 'Last Date', 'How Much'])

# %%
co = yf.Ticker("GOOG")
history = co.history(period="max", interval="3mo",)
print(history.index[0])
print(history.index[-1])
# Out:
# 2004-08-01 00:00:00-04:00
# 2023-05-01 00:00:00-04:00

# %%
co = yf.Ticker("GOOG")
history = co.history(period="max")
print(history.index[0])
print(history.index[-1])
# Out:
# 2004-08-19 00:00:00-04:00
# 2023-05-05 00:00:00-04:00

# %%
from datetime import datetime, timezone
 
# Get the datetime object using datetime
# module
dt_obj_w_tz = datetime.now()
print(dt_obj_w_tz)
 
# Add timezone information to the datetime
# object
dt_obj_w_tz = dt_obj_w_tz.replace(tzinfo=timezone.utc)
print(dt_obj_w_tz)
 
# Remove the timezone information from the datetime
# object
dt_obj_wo_tz = dt_obj_w_tz.replace(tzinfo=None)
print(dt_obj_wo_tz)
# Out:
# 2023-05-07 19:22:16.794701
# 2023-05-07 19:22:16.794701+00:00
# 2023-05-07 19:22:16.794701

# %%
type(history)
row = history.iloc[0]
date = history.index[0]
type(date)
print(date)
print(date.replace(tzinfo=None))
#history.dtypes
history.to_csv("teste.csv", date_format='%Y-%m-%d')
# Out:
# 2004-08-19 00:00:00-04:00
# 2004-08-19 00:00:00

# %%
def addRow(rows, company, ticker):
	co = yf.Ticker(ticker)
	history = co.history(period="max", interval="3mo")
	try:
		ipo = history.index[0].tz_localize(None)
		firstValue = history.iloc[0,0]
		lastValue = history.iloc[-1,0]
		lastDate = history.index[-1].tz_localize(None)
		howMuchPercent = ((lastValue - firstValue) / firstValue) * 100
	except:
		ipo = None
		firstValue = None
		lastValue = None
		lastDate = None
		howMuchPercent = None
	row = [company, ticker, ipo, firstValue, lastValue, lastDate, howMuchPercent]
	# add row in the dataframe
	rows.append(row)
	return 


columns = ['Company', 'Ticker', 'IPO', 'First Value', 'Last Value',
	   		 'Last Date', 'How Much']
rows = []
# Lê até encontrar as strings que indicam final
while True:
	page = pages[p]
	page_content = page.extract_text()
	parsed = ''.join(page_content)
	splited = parsed.split('\n')
	print("\n\n---------------------")
	print("Página " + str(p+1))
	print("---------------------\n")
	if p != 9: # Tratamento normal - a não ser a página 10 (no else) que está fora do padrão
		c = 0
		#cabeçalhos
		print(splited[c] + " | " + splited[c+1])
		c += 2
		ended = False
		while splited[c] != "June 24, 2022": #String do fim de cada página
			if splited[c] == "ftserussell.com": #String no final de toda a lista
				print("----------------\nTerminou\n----------------")
				ended = True
				break
			company = splited[c]
			ticker = splited[c+1]
			addRow(rows, company, ticker)
			#df.loc[len(df.index)] = [company, ticker, ipo, firstValue, lastValue, lastDate, howMuchPercent]
			print( company + " | " + ticker + " | ̭̭" + str(ipo) + " | ̭̭" + str(firstValue) + " | ̭̭" + str(lastValue) + " | ̭̭" + str(lastDate) + " | ̭̭" + str(howMuchPercent))
			c += 2
			#df.to_csv('SuperTempShares.csv', date_format="%d/%m/%Y")
			df = pd.DataFrame(rows, columns = columns)
			print(df)
			df.to_excel('SuperTempShares.xlsx')


	else:
		# Na página 10 o PDF fica sem quebra de linhas entre colunas
		
		# cabeçalhos
		c = 0
		# separa o ticker, que está no lado direito
		headers = splited[c].rsplit(maxsplit=1)
		print(headers[0] + " | " + headers[1])
		c += 1
		while splited[c][:13] != "June 24, 2022":
			# separa o ticker, que está a direita
			subsplited = splited[c].rsplit(maxsplit=1)
			company = subsplited[0]
			ticker = subsplited[1]
			addRow(rows, ticker)
			#df.loc[len(df.index)] = [company, ticker, ipo, firstValue, lastValue, lastDate, howMuchPercent]
			print( company + " | " + ticker + " | ̭̭" + str(ipo) + " | ̭̭" + str(firstValue) + " | ̭̭" + str(lastValue) + " | ̭̭" + str(lastDate) + " | ̭̭" + str(howMuchPercent))
			c += 1

	if ended:
		print("----------------\nTerminou Mesmo\n----------------")
		break

	p += 1
	df = pd.DataFrame(rows, columns = columns)
	
	#print(df)
	#df.to_excel('TempShares.xlsx')

print(df)
df.to_excel('Shares.xlsx')

#print("Sem eliminar as quebras")
#print(parsed)

#parsed = re.sub('n', '', parsed)
#print("Após eliminar as quebras")
#print(parsed)

#print("Pegando apenas as 20 primeiras posições")
#novastring = parsed[0:20]
#print(novastring)
# Out:
# ---------------------
# Página 3
# ---------------------
#
# Company | Ticker
# APELLIS PHARMACEUTICALS | APLS | ̭̭2017-11-01 00:00:00-04:00 | ̭̭13.869999885559082 | ̭̭76.70999908447266 | ̭̭2023-05-01 00:00:00-04:00 | ̭̭453.06416523002423
#                    Company Ticker        IPO  First Value  Last Value
# 0  APELLIS PHARMACEUTICALS   APLS 2017-11-01        13.87   76.709999  \
#
#    Last Date    How Much
# 0 2023-05-01  453.064165
# ASTEC INDS INC | ASTE | ̭̭2017-11-01 00:00:00-04:00 | ̭̭13.869999885559082 | ̭̭76.70999908447266 | ̭̭2023-05-01 00:00:00-04:00 | ̭̭453.06416523002423
#                    Company Ticker        IPO  First Value  Last Value
# 0  APELLIS PHARMACEUTICALS   APLS 2017-11-01    13.870000   76.709999  \
# 1           ASTEC INDS INC   ASTE 1986-06-01     2.675383   41.200001
#
#    Last Date     How Much
# 0 2023-05-01   453.064165
# 1 2023-05-05  1439.966594
# ASTRA SPACE INC | ASTR | ̭̭2017-11-01 00:00:00-04:00 | ̭̭13.869999885559082 | ̭̭76.70999908447266 | ̭̭2023-05-01 00:00:00-04:00 | ̭̭453.06416523002423
#                    Company Ticker        IPO  First Value  Last Value
# 0  APELLIS PHARMACEUTICALS   APLS 2017-11-01    13.870000   76.709999  \
# 1           ASTEC INDS INC   ASTE 1986-06-01     2.675383   41.200001
# 2          ASTRA SPACE INC   ASTR 2020-10-01     9.790000    0.448000
#
#    Last Date     How Much
# 0 2023-05-01   453.064165
# 1 2023-05-05  1439.966594
# 2 2023-04-01   -95.423902
# /tmp/ipykernel_127498/2074426207.py:9: RuntimeWarning: divide by zero encountered in double_scalars
#   howMuchPercent = ((lastValue - firstValue) / firstValue) * 100
# ASTRONICS | ATRO | ̭̭2017-11-01 00:00:00-04:00 | ̭̭13.869999885559082 | ̭̭76.70999908447266 | ̭̭2023-05-01 00:00:00-04:00 | ̭̭453.06416523002423
#                    Company Ticker        IPO  First Value  Last Value
# 0  APELLIS PHARMACEUTICALS   APLS 2017-11-01    13.870000   76.709999  \
# 1           ASTEC INDS INC   ASTE 1986-06-01     2.675383   41.200001
# 2          ASTRA SPACE INC   ASTR 2020-10-01     9.790000    0.448000
# 3                ASTRONICS   ATRO 1984-12-01     0.000000   14.690000
#
#    Last Date     How Much
# 0 2023-05-01   453.064165
# 1 2023-05-05  1439.966594
# 2 2023-04-01   -95.423902
# 3 2023-05-05          inf
# ATARA BIOTHERAPEUTICS | ATRA | ̭̭2017-11-01 00:00:00-04:00 | ̭̭13.869999885559082 | ̭̭76.70999908447266 | ̭̭2023-05-01 00:00:00-04:00 | ̭̭453.06416523002423
#                    Company Ticker        IPO  First Value  Last Value
# 0  APELLIS PHARMACEUTICALS   APLS 2017-11-01    13.870000   76.709999  \
# 1           ASTEC INDS INC   ASTE 1986-06-01     2.675383   41.200001
# 2          ASTRA SPACE INC   ASTR 2020-10-01     9.790000    0.448000
# 3                ASTRONICS   ATRO 1984-12-01     0.000000   14.690000
# 4    ATARA BIOTHERAPEUTICS   ATRA 2014-10-01    19.000000    2.860000
#
#    Last Date     How Much
# 0 2023-05-01   453.064165
# 1 2023-05-05  1439.966594
# 2 2023-04-01   -95.423902
# 3 2023-05-05          inf
# 4 2023-04-01   -84.947369
# ATEA PHARMACEUTICALS | AVIR | ̭̭2017-11-01 00:00:00-04:00 | ̭̭13.869999885559082 | ̭̭76.70999908447266 | ̭̭2023-05-01 00:00:00-04:00 | ̭̭453.06416523002423
#                    Company Ticker        IPO  First Value  Last Value
# 0  APELLIS PHARMACEUTICALS   APLS 2017-11-01    13.870000   76.709999  \
# 1           ASTEC INDS INC   ASTE 1986-06-01     2.675383   41.200001
# 2          ASTRA SPACE INC   ASTR 2020-10-01     9.790000    0.448000
# 3                ASTRONICS   ATRO 1984-12-01     0.000000   14.690000
# 4    ATARA BIOTHERAPEUTICS   ATRA 2014-10-01    19.000000    2.860000
# 5     ATEA PHARMACEUTICALS   AVIR 2020-10-01    29.940001    3.320000
#
#    Last Date     How Much
# 0 2023-05-01   453.064165
# 1 2023-05-05  1439.966594
# 2 2023-04-01   -95.423902
# 3 2023-05-05          inf
# 4 2023-04-01   -84.947369
# 5 2023-04-01   -88.911156
# ATERIAN INC | ATER | ̭̭2017-11-01 00:00:00-04:00 | ̭̭13.869999885559082 | ̭̭76.70999908447266 | ̭̭2023-05-01 00:00:00-04:00 | ̭̭453.06416523002423
#                    Company Ticker        IPO  First Value  Last Value
# 0  APELLIS PHARMACEUTICALS   APLS 2017-11-01    13.870000   76.709999  \
# 1           ASTEC INDS INC   ASTE 1986-06-01     2.675383   41.200001
# 2          ASTRA SPACE INC   ASTR 2020-10-01     9.790000    0.448000
# 3                ASTRONICS   ATRO 1984-12-01     0.000000   14.690000
# 4    ATARA BIOTHERAPEUTICS   ATRA 2014-10-01    19.000000    2.860000
# 5     ATEA PHARMACEUTICALS   AVIR 2020-10-01    29.940001    3.320000
# 6              ATERIAN INC   ATER 2019-06-01     8.160000    0.716200
#
#    Last Date     How Much
# 0 2023-05-01   453.064165
# 1 2023-05-05  1439.966594
# 2 2023-04-01   -95.423902
# 3 2023-05-05          inf
# 4 2023-04-01   -84.947369
# 5 2023-04-01   -88.911156
# 6 2023-05-05   -91.223039
# ATHIRA PHARMA | ATHA | ̭̭2017-11-01 00:00:00-04:00 | ̭̭13.869999885559082 | ̭̭76.70999908447266 | ̭̭2023-05-01 00:00:00-04:00 | ̭̭453.06416523002423
#                    Company Ticker        IPO  First Value  Last Value
# 0  APELLIS PHARMACEUTICALS   APLS 2017-11-01    13.870000   76.709999  \
# 1           ASTEC INDS INC   ASTE 1986-06-01     2.675383   41.200001
# 2          ASTRA SPACE INC   ASTR 2020-10-01     9.790000    0.448000
# 3                ASTRONICS   ATRO 1984-12-01     0.000000   14.690000
# 4    ATARA BIOTHERAPEUTICS   ATRA 2014-10-01    19.000000    2.860000
# 5     ATEA PHARMACEUTICALS   AVIR 2020-10-01    29.940001    3.320000
# 6              ATERIAN INC   ATER 2019-06-01     8.160000    0.716200
# 7            ATHIRA PHARMA   ATHA 2020-09-01    18.250000    2.960000
#
#    Last Date     How Much
# 0 2023-05-01   453.064165
# 1 2023-05-05  1439.966594
# 2 2023-04-01   -95.423902
# 3 2023-05-05          inf
# 4 2023-04-01   -84.947369
# 5 2023-04-01   -88.911156
# 6 2023-05-05   -91.223039
# 7 2023-05-05   -83.780822
# ATI PHYSICAL THERAPY INC (A) | ATIP | ̭̭2017-11-01 00:00:00-04:00 | ̭̭13.869999885559082 | ̭̭76.70999908447266 | ̭̭2023-05-01 00:00:00-04:00 | ̭̭453.06416523002423
#                         Company Ticker        IPO  First Value  Last Value
# 0       APELLIS PHARMACEUTICALS   APLS 2017-11-01    13.870000   76.709999  \
# 1                ASTEC INDS INC   ASTE 1986-06-01     2.675383   41.200001
# 2               ASTRA SPACE INC   ASTR 2020-10-01     9.790000    0.448000
# 3                     ASTRONICS   ATRO 1984-12-01     0.000000   14.690000
# 4         ATARA BIOTHERAPEUTICS   ATRA 2014-10-01    19.000000    2.860000
# 5          ATEA PHARMACEUTICALS   AVIR 2020-10-01    29.940001    3.320000
# 6                   ATERIAN INC   ATER 2019-06-01     8.160000    0.716200
# 7                 ATHIRA PHARMA   ATHA 2020-09-01    18.250000    2.960000
# 8  ATI PHYSICAL THERAPY INC (A)   ATIP 2020-10-01     9.710000    0.266000
#
#    Last Date     How Much
# 0 2023-05-01   453.064165
# 1 2023-05-05  1439.966594
# 2 2023-04-01   -95.423902
# 3 2023-05-05          inf
# 4 2023-04-01   -84.947369
# 5 2023-04-01   -88.911156
# 6 2023-05-05   -91.223039
# 7 2023-05-05   -83.780822
# 8 2023-04-01   -97.260556
# ATKORE INC | ATKR | ̭̭2017-11-01 00:00:00-04:00 | ̭̭13.869999885559082 | ̭̭76.70999908447266 | ̭̭2023-05-01 00:00:00-04:00 | ̭̭453.06416523002423
#                         Company Ticker        IPO  First Value  Last Value
# 0       APELLIS PHARMACEUTICALS   APLS 2017-11-01    13.870000   76.709999  \
# 1                ASTEC INDS INC   ASTE 1986-06-01     2.675383   41.200001
# 2               ASTRA SPACE INC   ASTR 2020-10-01     9.790000    0.448000
# 3                     ASTRONICS   ATRO 1984-12-01     0.000000   14.690000
# 4         ATARA BIOTHERAPEUTICS   ATRA 2014-10-01    19.000000    2.860000
# 5          ATEA PHARMACEUTICALS   AVIR 2020-10-01    29.940001    3.320000
# 6                   ATERIAN INC   ATER 2019-06-01     8.160000    0.716200
# 7                 ATHIRA PHARMA   ATHA 2020-09-01    18.250000    2.960000
# 8  ATI PHYSICAL THERAPY INC (A)   ATIP 2020-10-01     9.710000    0.266000
# 9                    ATKORE INC   ATKR 2016-06-01    16.090000  125.559998
#
#    Last Date     How Much
# 0 2023-05-01   453.064165
# 1 2023-05-05  1439.966594
# 2 2023-04-01   -95.423902
# 3 2023-05-05          inf
# 4 2023-04-01   -84.947369
# 5 2023-04-01   -88.911156
# 6 2023-05-05   -91.223039
# 7 2023-05-05   -83.780822
# 8 2023-04-01   -97.260556
# 9 2023-05-05   680.360450
# ATLANTIC UNION BANKSHARES | AUB | ̭̭2017-11-01 00:00:00-04:00 | ̭̭13.869999885559082 | ̭̭76.70999908447266 | ̭̭2023-05-01 00:00:00-04:00 | ̭̭453.06416523002423
# 9  2023-05-05   680.360450
# 10 2023-04-01   772.138061
# 11 2023-04-01    89.949672
# ATLAS AIR WORLDWIDE HOLDINGS | AAWW | ̭̭2017-11-01 00:00:00-04:00 | ̭̭13.869999885559082 | ̭̭76.70999908447266 | ̭̭2023-05-01 00:00:00-04:00 | ̭̭453.06416523002423
#                          Company Ticker        IPO  First Value  Last Value
# 0        APELLIS PHARMACEUTICALS   APLS 2017-11-01    13.870000   76.709999  \
# 1                 ASTEC INDS INC   ASTE 1986-06-01     2.675383   41.200001
# 2                ASTRA SPACE INC   ASTR 2020-10-01     9.790000    0.448000
# 3                      ASTRONICS   ATRO 1984-12-01     0.000000   14.690000
# 4          ATARA BIOTHERAPEUTICS   ATRA 2014-10-01    19.000000    2.860000
# 5           ATEA PHARMACEUTICALS   AVIR 2020-10-01    29.940001    3.320000
# 6                    ATERIAN INC   ATER 2019-06-01     8.160000    0.716200
# 7                  ATHIRA PHARMA   ATHA 2020-09-01    18.250000    2.960000
# 8   ATI PHYSICAL THERAPY INC (A)   ATIP 2020-10-01     9.710000    0.266000
# 9                     ATKORE INC   ATKR 2016-06-01    16.090000  125.559998
# 10     ATLANTIC UNION BANKSHARES    AUB 1993-10-01     3.993634   34.830002
# 11      ATLANTICUS HOLDINGS CORP   ATLC 1999-04-01    14.361699   27.280001
# 12  ATLAS AIR WORLDWIDE HOLDINGS   AAWW 2004-07-01    16.850000  100.870003
#
#     Last Date     How Much
# 0  2023-05-01   453.064165
# 1  2023-05-05  1439.966594
# 2  2023-04-01   -95.423902
# 3  2023-05-05          inf
# 4  2023-04-01   -84.947369
# 5  2023-04-01   -88.911156
# 6  2023-05-05   -91.223039
# 7  2023-05-05   -83.780822
# 8  2023-04-01   -97.260556
# 9  2023-05-05   680.360450
# 10 2023-04-01   772.138061
# 11 2023-04-01    89.949672
# 12 2023-01-01   498.635018
# ATLAS TECHNICAL CONSULTANTS INC (A) | ATCX | ̭̭2017-11-01 00:00:00-04:00 | ̭̭13.869999885559082 | ̭̭76.70999908447266 | ̭̭2023-05-01 00:00:00-04:00 | ̭̭453.06416523002423
#                                 Company Ticker        IPO  First Value
# 0               APELLIS PHARMACEUTICALS   APLS 2017-11-01    13.870000  \
# 1                        ASTEC INDS INC   ASTE 1986-06-01     2.675383
# 2                       ASTRA SPACE INC   ASTR 2020-10-01     9.790000
# 3                             ASTRONICS   ATRO 1984-12-01     0.000000
# 4                 ATARA BIOTHERAPEUTICS   ATRA 2014-10-01    19.000000
# 5                  ATEA PHARMACEUTICALS   AVIR 2020-10-01    29.940001
# 6                           ATERIAN INC   ATER 2019-06-01     8.160000
# 7                         ATHIRA PHARMA   ATHA 2020-09-01    18.250000
# 8          ATI PHYSICAL THERAPY INC (A)   ATIP 2020-10-01     9.710000
# 9                            ATKORE INC   ATKR 2016-06-01    16.090000
# 10            ATLANTIC UNION BANKSHARES    AUB 1993-10-01     3.993634
# ATOMERA | ATOM | ̭̭2017-11-01 00:00:00-04:00 | ̭̭13.869999885559082 | ̭̭76.70999908447266 | ̭̭2023-05-01 00:00:00-04:00 | ̭̭453.06416523002423
#                                 Company Ticker        IPO  First Value
# 0               APELLIS PHARMACEUTICALS   APLS 2017-11-01    13.870000  \
# 1                        ASTEC INDS INC   ASTE 1986-06-01     2.675383
# 2                       ASTRA SPACE INC   ASTR 2020-10-01     9.790000
# 3                             ASTRONICS   ATRO 1984-12-01     0.000000
# 4                 ATARA BIOTHERAPEUTICS   ATRA 2014-10-01    19.000000
# 5                  ATEA PHARMACEUTICALS   AVIR 2020-10-01    29.940001
# 6                           ATERIAN INC   ATER 2019-06-01     8.160000
# 7                         ATHIRA PHARMA   ATHA 2020-09-01    18.250000
# 8          ATI PHYSICAL THERAPY INC (A)   ATIP 2020-10-01     9.710000
# 9                            ATKORE INC   ATKR 2016-06-01    16.090000
# 10            ATLANTIC UNION BANKSHARES    AUB 1993-10-01     3.993634
# 11             ATLANTICUS HOLDINGS CORP   ATLC 1999-04-01    14.361699
# 12         ATLAS AIR WORLDWIDE HOLDINGS   AAWW 2004-07-01    16.850000
# 13  ATLAS TECHNICAL CONSULTANTS INC (A)   ATCX 2019-01-01    10.426000
# 14                    ATN INTERNATIONAL   ATNI 1991-11-01     4.110885
# 15                              ATOMERA   ATOM 2016-08-01     9.378000
#
#     Last Value  Last Date     How Much
# 0    76.709999 2023-05-01   453.064165
# 1    41.200001 2023-05-05  1439.966594
# 2     0.448000 2023-04-01   -95.423902
# 3    14.690000 2023-05-05          inf
# 4     2.860000 2023-04-01   -84.947369
# 5     3.320000 2023-04-01   -88.911156
# 6     0.716200 2023-05-05   -91.223039
# 7     2.960000 2023-05-05   -83.780822
# 8     0.266000 2023-04-01   -97.260556
# 9   125.559998 2023-05-05   680.360450
# 10   34.830002 2023-04-01   772.138061
# 11   27.280001 2023-04-01    89.949672
# 12  100.870003 2023-01-01   498.635018
# 13   12.190000 2023-04-01    16.919240
# 14   36.209999 2023-05-01   780.832192
# 15    7.920000 2023-05-01   -15.547026
# ATRICURE | ATRC | ̭̭2017-11-01 00:00:00-04:00 | ̭̭13.869999885559082 | ̭̭76.70999908447266 | ̭̭2023-05-01 00:00:00-04:00 | ̭̭453.06416523002423
#                                 Company Ticker        IPO  First Value
# 0               APELLIS PHARMACEUTICALS   APLS 2017-11-01    13.870000  \
# 1                        ASTEC INDS INC   ASTE 1986-06-01     2.675383
# 2                       ASTRA SPACE INC   ASTR 2020-10-01     9.790000
# 3                             ASTRONICS   ATRO 1984-12-01     0.000000
# 4                 ATARA BIOTHERAPEUTICS   ATRA 2014-10-01    19.000000
# 5                  ATEA PHARMACEUTICALS   AVIR 2020-10-01    29.940001
# 6                           ATERIAN INC   ATER 2019-06-01     8.160000
# 7                         ATHIRA PHARMA   ATHA 2020-09-01    18.250000
# 8          ATI PHYSICAL THERAPY INC (A)   ATIP 2020-10-01     9.710000
# 9                            ATKORE INC   ATKR 2016-06-01    16.090000
# 16   44.310001 2023-05-01   230.671661
# 17  613.156311 2023-05-05  4850.114391
# 18    0.130000 2023-04-01   -99.429499
# AURA BIOSCIENCES | AURA | ̭̭2017-11-01 00:00:00-04:00 | ̭̭13.869999885559082 | ̭̭76.70999908447266 | ̭̭2023-05-01 00:00:00-04:00 | ̭̭453.06416523002423
#                                 Company Ticker        IPO  First Value
# 0               APELLIS PHARMACEUTICALS   APLS 2017-11-01    13.870000  \
# 1                        ASTEC INDS INC   ASTE 1986-06-01     2.675383
# 2                       ASTRA SPACE INC   ASTR 2020-10-01     9.790000
# 3                             ASTRONICS   ATRO 1984-12-01     0.000000
# 4                 ATARA BIOTHERAPEUTICS   ATRA 2014-10-01    19.000000
# 5                  ATEA PHARMACEUTICALS   AVIR 2020-10-01    29.940001
# 6                           ATERIAN INC   ATER 2019-06-01     8.160000
# 7                         ATHIRA PHARMA   ATHA 2020-09-01    18.250000
# 8          ATI PHYSICAL THERAPY INC (A)   ATIP 2020-10-01     9.710000
# 9                            ATKORE INC   ATKR 2016-06-01    16.090000
# 10            ATLANTIC UNION BANKSHARES    AUB 1993-10-01     3.993634
# 11             ATLANTICUS HOLDINGS CORP   ATLC 1999-04-01    14.361699
# 12         ATLAS AIR WORLDWIDE HOLDINGS   AAWW 2004-07-01    16.850000
# 13  ATLAS TECHNICAL CONSULTANTS INC (A)   ATCX 2019-01-01    10.426000
# 14                    ATN INTERNATIONAL   ATNI 1991-11-01     4.110885
# 15                              ATOMERA   ATOM 2016-08-01     9.378000
# 16                             ATRICURE   ATRC 2005-08-01    13.400000
# 17                          ATRION CORP   ATRI 1984-12-01    12.386710
# 18                               AUDACY    AUD 1999-01-01    22.786970
# 19                     AURA BIOSCIENCES   AURA 2021-10-01    14.850000
#
#     Last Value  Last Date     How Much
# 0    76.709999 2023-05-01   453.064165
# 1    41.200001 2023-05-05  1439.966594
# 2     0.448000 2023-04-01   -95.423902
# 3    14.690000 2023-05-05          inf
# 4     2.860000 2023-04-01   -84.947369
# 5     3.320000 2023-04-01   -88.911156
# 6     0.716200 2023-05-05   -91.223039
# 7     2.960000 2023-05-05   -83.780822
# 8     0.266000 2023-04-01   -97.260556
# 9   125.559998 2023-05-05   680.360450
# 10   34.830002 2023-04-01   772.138061
# 11   27.280001 2023-04-01    89.949672
# 12  100.870003 2023-01-01   498.635018
# 13   12.190000 2023-04-01    16.919240
# 14   36.209999 2023-05-01   780.832192
# 15    7.920000 2023-05-01   -15.547026
# 16   44.310001 2023-05-01   230.671661
# 17  613.156311 2023-05-05  4850.114391
# 18    0.130000 2023-04-01   -99.429499
# 19    9.280000 2023-04-01   -37.508421
# AURINIA PHARMACEUTICALS NASDAQ | AUPH | ̭̭2017-11-01 00:00:00-04:00 | ̭̭13.869999885559082 | ̭̭76.70999908447266 | ̭̭2023-05-01 00:00:00-04:00 | ̭̭453.06416523002423
#                                 Company Ticker        IPO  First Value
# 0               APELLIS PHARMACEUTICALS   APLS 2017-11-01    13.870000  \
# 1                        ASTEC INDS INC   ASTE 1986-06-01     2.675383
# 2                       ASTRA SPACE INC   ASTR 2020-10-01     9.790000
# 3                             ASTRONICS   ATRO 1984-12-01     0.000000
# 4                 ATARA BIOTHERAPEUTICS   ATRA 2014-10-01    19.000000
# 5                  ATEA PHARMACEUTICALS   AVIR 2020-10-01    29.940001
# 6                           ATERIAN INC   ATER 2019-06-01     8.160000
# 7                         ATHIRA PHARMA   ATHA 2020-09-01    18.250000
# 8          ATI PHYSICAL THERAPY INC (A)   ATIP 2020-10-01     9.710000
# 9                            ATKORE INC   ATKR 2016-06-01    16.090000
# 10            ATLANTIC UNION BANKSHARES    AUB 1993-10-01     3.993634
# 11             ATLANTICUS HOLDINGS CORP   ATLC 1999-04-01    14.361699
# 12         ATLAS AIR WORLDWIDE HOLDINGS   AAWW 2004-07-01    16.850000
# 13  ATLAS TECHNICAL CONSULTANTS INC (A)   ATCX 2019-01-01    10.426000
# 14                    ATN INTERNATIONAL   ATNI 1991-11-01     4.110885
# 15                              ATOMERA   ATOM 2016-08-01     9.378000
# 16                             ATRICURE   ATRC 2005-08-01    13.400000
# 17                          ATRION CORP   ATRI 1984-12-01    12.386710
# 18                               AUDACY    AUD 1999-01-01    22.786970
# 19                     AURA BIOSCIENCES   AURA 2021-10-01    14.850000
# 20       AURINIA PHARMACEUTICALS NASDAQ   AUPH 2014-09-01     3.200000
#
#     Last Value  Last Date     How Much
# 0    76.709999 2023-05-01   453.064165
# 1    41.200001 2023-05-05  1439.966594
# 2     0.448000 2023-04-01   -95.423902
# 3    14.690000 2023-05-05          inf
# 4     2.860000 2023-04-01   -84.947369
# 5     3.320000 2023-04-01   -88.911156
# 6     0.716200 2023-05-05   -91.223039
# 7     2.960000 2023-05-05   -83.780822
# 8     0.266000 2023-04-01   -97.260556
# 9   125.559998 2023-05-05   680.360450
# 10   34.830002 2023-04-01   772.138061
# 11   27.280001 2023-04-01    89.949672
# 12  100.870003 2023-01-01   498.635018
# 13   12.190000 2023-04-01    16.919240
# 14   36.209999 2023-05-01   780.832192
# 15    7.920000 2023-05-01   -15.547026
# 16   44.310001 2023-05-01   230.671661
# 17  613.156311 2023-05-05  4850.114391
# 18    0.130000 2023-04-01   -99.429499
# 19    9.280000 2023-04-01   -37.508421
# 20   11.525000 2023-05-05   260.156233
# AVANOS MEDICAL | AVNS | ̭̭2017-11-01 00:00:00-04:00 | ̭̭13.869999885559082 | ̭̭76.70999908447266 | ̭̭2023-05-01 00:00:00-04:00 | ̭̭453.06416523002423
#                                 Company Ticker        IPO  First Value
# 0               APELLIS PHARMACEUTICALS   APLS 2017-11-01    13.870000  \
# 1                        ASTEC INDS INC   ASTE 1986-06-01     2.675383
# 2                       ASTRA SPACE INC   ASTR 2020-10-01     9.790000
# 3                             ASTRONICS   ATRO 1984-12-01     0.000000
# 4                 ATARA BIOTHERAPEUTICS   ATRA 2014-10-01    19.000000
# 5                  ATEA PHARMACEUTICALS   AVIR 2020-10-01    29.940001
# 6                           ATERIAN INC   ATER 2019-06-01     8.160000
# 7                         ATHIRA PHARMA   ATHA 2020-09-01    18.250000
# 8          ATI PHYSICAL THERAPY INC (A)   ATIP 2020-10-01     9.710000
# 9                            ATKORE INC   ATKR 2016-06-01    16.090000
# 10            ATLANTIC UNION BANKSHARES    AUB 1993-10-01     3.993634
# 11             ATLANTICUS HOLDINGS CORP   ATLC 1999-04-01    14.361699
# 12         ATLAS AIR WORLDWIDE HOLDINGS   AAWW 2004-07-01    16.850000
# 13  ATLAS TECHNICAL CONSULTANTS INC (A)   ATCX 2019-01-01    10.426000
# 14                    ATN INTERNATIONAL   ATNI 1991-11-01     4.110885
# 15                              ATOMERA   ATOM 2016-08-01     9.378000
# 16                             ATRICURE   ATRC 2005-08-01    13.400000
# 17                          ATRION CORP   ATRI 1984-12-01    12.386710
# 18                               AUDACY    AUD 1999-01-01    22.786970
# 19                     AURA BIOSCIENCES   AURA 2021-10-01    14.850000
# 20       AURINIA PHARMACEUTICALS NASDAQ   AUPH 2014-09-01     3.200000
# 21                       AVANOS MEDICAL   AVNS 2014-10-01    37.520000
#
#     Last Value  Last Date     How Much
# 0    76.709999 2023-05-01   453.064165
# 1    41.200001 2023-05-05  1439.966594
# 2     0.448000 2023-04-01   -95.423902
# 3    14.690000 2023-05-05          inf
# 4     2.860000 2023-04-01   -84.947369
# 5     3.320000 2023-04-01   -88.911156
# 6     0.716200 2023-05-05   -91.223039
# 7     2.960000 2023-05-05   -83.780822
# 8     0.266000 2023-04-01   -97.260556
# 9   125.559998 2023-05-05   680.360450
# 10   34.830002 2023-04-01   772.138061
# 11   27.280001 2023-04-01    89.949672
# 12  100.870003 2023-01-01   498.635018
# 13   12.190000 2023-04-01    16.919240
# 14   36.209999 2023-05-01   780.832192
# 15    7.920000 2023-05-01   -15.547026
# 16   44.310001 2023-05-01   230.671661
# 17  613.156311 2023-05-05  4850.114391
# 18    0.130000 2023-04-01   -99.429499
# 19    9.280000 2023-04-01   -37.508421
# 20   11.525000 2023-05-05   260.156233
# 21   29.610001 2023-04-01   -21.082089
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_127498/2074426207.py in <module>
#      45                         company = splited[c]
#      46                         ticker = splited[c+1]
# ---> 47                         addRow(rows, company, ticker)
#      48                         #df.loc[len(df.index)] = [company, ticker, ipo, firstValue, lastValue, lastDate, howMuchPercent]
#      49                         print( company + " | " + ticker + " | ̭̭" + str(ipo) + " | ̭̭" + str(firstValue) + " | ̭̭" + str(lastValue) + " | ̭̭" + str(lastDate) + " | ̭̭" + str(howMuchPercent))
#
# /tmp/ipykernel_127498/2074426207.py in addRow(rows, company, ticker)
#       1 def addRow(rows, company, ticker):
#       2         co = yf.Ticker(ticker)
# ----> 3         history = co.history(period="max", interval="3mo")
#       4         try:
#       5                 ipo = history.index[0].tz_localize(None)
#
# ~/.local/lib/python3.10/site-packages/yfinance/base.py in history(self, period, interval, start, end, prepost, actions, auto_adjust, back_adjust, repair, keepna, proxy, rounding, timeout, debug, raise_errors)
#     142         if start or period is None or period.lower() == "max":
#     143             # Check can get TZ. Fail => probably delisted
# --> 144             tz = self._get_ticker_tz(debug, proxy, timeout)
#     145             if tz is None:
#     146                 # Every valid ticker has a timezone. Missing = problem
#
# ~/.local/lib/python3.10/site-packages/yfinance/base.py in _get_ticker_tz(self, debug_mode, proxy, timeout)
#     935
#     936         if tz is None:
# --> 937             tz = self._fetch_ticker_tz(debug_mode, proxy, timeout)
#     938
#     939             if utils.is_valid_timezone(tz):
#
# ~/.local/lib/python3.10/site-packages/yfinance/base.py in _fetch_ticker_tz(self, debug_mode, proxy, timeout)
#     955
#     956         try:
# --> 957             data = self._data.cache_get(url=url, params=params, proxy=proxy, timeout=timeout)
#     958             data = data.json()
#     959         except Exception as e:
#
# ~/.local/lib/python3.10/site-packages/yfinance/data.py in wrapped(*args, **kwargs)
#      41         args = tuple([tuple(arg) if isinstance(arg, list) else arg for arg in args])
#      42         kwargs = {k: tuple(v) if isinstance(v, list) else v for k, v in kwargs.items()}
# ---> 43         return func(*args, **kwargs)
#      44
#      45     # copy over the lru_cache extra methods to this wrapper to be able to access them
#
# ~/.local/lib/python3.10/site-packages/yfinance/data.py in cache_get(self, url, user_agent_headers, params, proxy, timeout)
#     195     @lru_cache(maxsize=cache_maxsize)
#     196     def cache_get(self, url, user_agent_headers=None, params=None, proxy=None, timeout=30):
# --> 197         return self.get(url, user_agent_headers, params, proxy, timeout)
#     198
#     199     def _get_proxy(self, proxy):
#
# ~/.local/lib/python3.10/site-packages/yfinance/data.py in get(self, url, user_agent_headers, params, proxy, timeout)
#     184     def get(self, url, user_agent_headers=None, params=None, proxy=None, timeout=30):
#     185         proxy = self._get_proxy(proxy)
# --> 186         response = self._session.get(
#     187             url=url,
#     188             params=params,
#
# ~/.local/lib/python3.10/site-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# ~/.local/lib/python3.10/site-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# ~/.local/lib/python3.10/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     585         }
#     586         send_kwargs.update(settings)
# --> 587         resp = self.send(prep, **send_kwargs)
#     588
#     589         return resp
#
# ~/.local/lib/python3.10/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     699
#     700         # Send the request
# --> 701         r = adapter.send(request, **kwargs)
#     702
#     703         # Total elapsed time of the request (approximately)
#
# ~/.local/lib/python3.10/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     487         try:
#     488             if not chunked:
# --> 489                 resp = conn.urlopen(
#     490                     method=request.method,
#     491                     url=url,
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380         # Trigger any extra validation we need to do.
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#     384             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#    1010         # Force connect early to allow us to validate the connection.
#    1011         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1012             conn.connect()
#    1013
#    1014         if not conn.is_verified:
#
# /usr/lib/python3/dist-packages/urllib3/connection.py in connect(self)
#     351     def connect(self):
#     352         # Add certificate verification
# --> 353         conn = self._new_conn()
#     354         hostname = self.host
#     355         tls_in_tls = False
#
# /usr/lib/python3/dist-packages/urllib3/connection.py in _new_conn(self)
#     167
#     168         try:
# --> 169             conn = connection.create_connection(
#     170                 (self._dns_host, self.port), self.timeout, **extra_kw
#     171             )
#
# /usr/lib/python3/dist-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      84             if source_address:
#      85                 sock.bind(source_address)
# ---> 86             sock.connect(sa)
#      87             return sock
#      88
#
# KeyboardInterrupt:
